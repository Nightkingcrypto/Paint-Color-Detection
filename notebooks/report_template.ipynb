# %% [markdown]
# # Deep Learning Project with MLOps – Color Detector (VAE + GAN)
#
# Student: *Your Name*
# Index: *Your Index Number*
# Batch: HND 24.2F

# %% [markdown]
# ## 1. Problem Definition and Dataset Description
#
# - Clearly define the problem (color detection and most similar paint shades).
# - Mention assumptions (solid color patches, controlled lighting, etc.).
# - Describe the folder structure of the dataset and how brightness variations are stored.

# %% [markdown]
# ## 2. Model Development (VAE + GAN)
#
# - Explain the VAE architecture and latent space.
# - Explain how the GAN is used for data augmentation / VAE‑GAN.
# - Describe preprocessing steps.
# - Insert MLflow screenshots (loss curves, parameters, etc.).

# %% [markdown]
# ## 3. MLOps Implementation
#
# - **Version Control**: describe Git workflow, branches, and how code + configs are tracked.
# - **DVC**: explain how large datasets and models can be versioned.
# - **CI/CD**: describe GitHub Actions workflow and Docker image.
# - **Deployment**: explain FastAPI app and how the user uploads an image.
# - **Monitoring & Model Drift**: show how logs are collected and analysed.

# %% [markdown]
# ## 4. Experiments and Results
#
# - Summarise training/validation metrics.
# - Show example predictions (top‑3 colours for different inputs).
# - Discuss strengths, limitations and possible improvements.

# %% [markdown]
# ## 5. Conclusion
#
# - Short conclusion linking back to the coursework requirements.
# - Provide GitHub repository link and mention the demo video.
